# %% [markdown]
# <a href="https://colab.research.google.com/github/mrri-18/swu_3/blob/main/stands_nutrient_cluster.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing
import matplotlib.pyplot as plt # visualization
import seaborn as sns #visualization
from sklearn.preprocessing import StandardScaler
import scipy as sp

# %%
#import the dataset
#데이터셋을 불러온다
dataset = pd.read_csv('/content/food111_col.csv', encoding='UTF8')
dataset.head()
# Out:
#    Unnamed: 0                                   ATT_FILE_NO_MAIN  \
# 0           0  http://www.foodsafetykorea.go.kr/uploadimg/coo...
# 1           1  http://www.foodsafetykorea.go.kr/uploadimg/coo...
# 2           2  http://www.foodsafetykorea.go.kr/uploadimg/coo...
# 3           3  http://www.foodsafetykorea.go.kr/uploadimg/coo...
# 4           4  http://www.foodsafetykorea.go.kr/uploadimg/coo...
#
#                                       ATT_FILE_NO_MK HASH_TAG  INFO_CAR  \
# 0  http://www.foodsafetykorea.go.kr/uploadimg/coo...      연두부       3.0
# 1  http://www.foodsafetykorea.go.kr/uploadimg/coo...     날콩가루      20.0
# 2  http://www.foodsafetykorea.go.kr/uploadimg/coo...    방울토마토       9.0
# 3  http://www.foodsafetykorea.go.kr/uploadimg/coo...      순두부      10.0
# 4  http://www.foodsafetykorea.go.kr/uploadimg/coo...      NaN       2.0
#
#    INFO_ENG  INFO_FAT  INFO_NA  INFO_PRO  INFO_WGT  ...  \
# 0     220.0      17.0     99.0      14.0       NaN  ...
# 1     215.0       9.0    240.0      14.0       NaN  ...
# 2      45.0       1.0    277.0       2.0       NaN  ...
# 3      75.0       2.0     22.0       4.0       NaN  ...
# 4      65.0       1.0     78.0      12.0       NaN  ...
#
#                                       RCP_PARTS_DTLS RCP_PAT2 RCP_SEQ  \
# 0  새우두부계란찜\n연두부 75g(3/4모), 칵테일새우 20g(5마리), 달걀 30g...       반찬    28.0
# 1  [1인분]조선부추 50g, 날콩가루 7g(1⅓작은술)\n·양념장 : 저염간장 3g(...       반찬    29.0
# 2  ●방울토마토 소박이 : \n방울토마토 150g(5개), 양파 10g(3×1cm), ...       반찬    31.0
# 3  ●오이무침 :\n오이 70g(1/3개), 다진 땅콩 10g(1큰술)\n●순두부사과 ...       반찬    32.0
# 4  북엇국\n북어채 25g(15개), 새우 10g(3마리), 사과 30g(1/5개), ...     국&찌개    33.0
#
#   RCP_WAY2 LOW_NA HIGH_PRO VEGAN LOW_FAT LOW_CAR LOW_ENG
# 0       찌기    0.0        1     1     NaN     NaN     NaN
# 1       찌기    0.0        1     1     NaN     NaN     NaN
# 2       기타    0.0        0     1     NaN     NaN     NaN
# 3       기타    0.0        0     1     NaN     NaN     NaN
# 4      끓이기    0.0        1     1     NaN     NaN     NaN
#
# [5 rows x 34 columns]

# %%
dataset.columns
# Out:
# Index(['Unnamed: 0', 'ATT_FILE_NO_MAIN', 'ATT_FILE_NO_MK', 'HASH_TAG',
#        'INFO_CAR', 'INFO_ENG', 'INFO_FAT', 'INFO_NA', 'INFO_PRO', 'INFO_WGT',
#        'MANUAL_IMG01', 'MANUAL_IMG02', 'MANUAL_IMG03', 'MANUAL_IMG04',
#        'MANUAL_IMG05', 'MANUAL_IMG06', 'MANUAL01', 'MANUAL02', 'MANUAL03',
#        'MANUAL04', 'MANUAL05', 'MANUAL06', 'RCP_NA_TIP', 'RCP_NM',
#        'RCP_PARTS_DTLS', 'RCP_PAT2', 'RCP_SEQ', 'RCP_WAY2', 'LOW_NA',
#        'HIGH_PRO', 'VEGAN', 'LOW_FAT', 'LOW_CAR', 'LOW_ENG'],
#       dtype='object')

# %%
dataset.shape
# Out:
# (1267, 34)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1267 entries, 0 to 1266
# Data columns (total 34 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1267 non-null   int64
#  1   ATT_FILE_NO_MAIN  1105 non-null   object
#  2   ATT_FILE_NO_MK    1109 non-null   object
#  3   HASH_TAG          356 non-null    object
#  4   INFO_CAR          1267 non-null   float64
#  5   INFO_ENG          1267 non-null   float64
#  6   INFO_FAT          1267 non-null   float64
#  7   INFO_NA           1267 non-null   float64
#  8   INFO_PRO          1267 non-null   float64
#  9   INFO_WGT          242 non-null    float64
#  10  MANUAL_IMG01      1109 non-null   object
#  11  MANUAL_IMG02      1110 non-null   object
#  12  MANUAL_IMG03      1111 non-null   object
#  13  MANUAL_IMG04      1061 non-null   object
#  14  MANUAL_IMG05      1058 non-null   object
#  15  MANUAL_IMG06      1004 non-null   object
#  16  MANUAL01          1109 non-null   object
#  17  MANUAL02          1110 non-null   object
#  18  MANUAL03          1111 non-null   object
#  19  MANUAL04          1061 non-null   object
#  20  MANUAL05          1058 non-null   object
#  21  MANUAL06          1004 non-null   object
#  22  RCP_NA_TIP        1057 non-null   object
#  23  RCP_NM            1267 non-null   object
#  24  RCP_PARTS_DTLS    1267 non-null   object
#  25  RCP_PAT2          1111 non-null   object
#  26  RCP_SEQ           1111 non-null   float64
#  27  RCP_WAY2          1111 non-null   object
#  28  LOW_NA            1111 non-null   float64
#  29  HIGH_PRO          1267 non-null   int64
#  30  VEGAN             1267 non-null   int64
#  31  LOW_FAT           0 non-null      float64
#  32  LOW_CAR           0 non-null      float64
#  33  LOW_ENG           0 non-null      float64
# dtypes: float64(11), int64(3), object(20)
# memory usage: 336.7+ KB

# %%
dataset.isnull().sum()
# Out:
# Unnamed: 0             0
# ATT_FILE_NO_MAIN     162
# ATT_FILE_NO_MK       158
# HASH_TAG             911
# INFO_CAR               0
# INFO_ENG               0
# INFO_FAT               0
# INFO_NA                0
# INFO_PRO               0
# INFO_WGT            1025
# MANUAL_IMG01         158
# MANUAL_IMG02         157
# MANUAL_IMG03         156
# MANUAL_IMG04         206
# MANUAL_IMG05         209
# MANUAL_IMG06         263
# MANUAL01             158
# MANUAL02             157
# MANUAL03             156
# MANUAL04             206
# MANUAL05             209
# MANUAL06             263
# RCP_NA_TIP           210
# RCP_NM                 0
# RCP_PARTS_DTLS         0
# RCP_PAT2             156
# RCP_SEQ              156
# RCP_WAY2             156
# LOW_NA               156
# HIGH_PRO               0
# VEGAN                  0
# LOW_FAT             1267
# LOW_CAR             1267
# LOW_ENG             1267
# dtype: int64

# %%
# 특정 행(index)을 출력 (예시에서는 2번째 행)
specific_row = dataset.iloc[493]  # 0부터 시작하는 인덱스

# 결과 출력
print(specific_row)
# Out:
# Unnamed: 0                                                        493
# ATT_FILE_NO_MAIN    http://www.foodsafetykorea.go.kr/uploadimg/201...
# ATT_FILE_NO_MK      http://www.foodsafetykorea.go.kr/uploadimg/201...
# HASH_TAG                                                          NaN
# INFO_CAR                                                          6.2
# INFO_ENG                                                         86.7
# INFO_FAT                                                          5.9
# INFO_NA                                                         577.2
# INFO_PRO                                                          9.5
# INFO_WGT                                                          NaN
# MANUAL_IMG01        http://www.foodsafetykorea.go.kr/uploadimg/coo...
# MANUAL_IMG02        http://www.foodsafetykorea.go.kr/uploadimg/coo...
# MANUAL_IMG03        http://www.foodsafetykorea.go.kr/uploadimg/coo...
# MANUAL_IMG04        http://www.foodsafetykorea.go.kr/uploadimg/coo...
# MANUAL_IMG05        http://www.foodsafetykorea.go.kr/uploadimg/coo...
# MANUAL_IMG06        http://www.foodsafetykorea.go.kr/uploadimg/coo...
# MANUAL01                     1. 물 1컵 반에 국멸치와 건다시마를 넣고 멸치다시마국물 1컵을 낸다.
# MANUAL02                       2. 호박잎은 줄기를 꺾으며 잡아당겨 실 같은 껍질을 벗기고 씻는다.
# MANUAL03            3. 멸치다시마국물 1컵에 된장을 풀고 씻은 다슬기살을 함께 넣어 중불에서 5분정도...
# MANUAL04                                  4. 국물낸 다슬기는 건져 달걀물과 함께 섞는다.
# MANUAL05                           5. 부추는 1cm 가량의 크기로 썰고 대파는 어슷썰기 한다.
# MANUAL06            6. 국물이 끓어 오르면 호박잎과 부추, 파, 다진 마늘을 넣고 마지막으로 달걀물을...
# RCP_NA_TIP          호박잎은 비벼서 연하게 만든 후 사용한다. - 다슬기를 달걀물에 묻혀 넣으면 달걀이...
# RCP_NM                                                      호박잎다슬기된장국
# RCP_PARTS_DTLS      다슬기살 20g, 호박잎 20g , 부추 15g, 달걀 15g, 물 300g, 된장...
# RCP_PAT2                                                         국&찌개
# RCP_SEQ                                                         691.0
# RCP_WAY2                                                          끓이기
# LOW_NA                                                            0.0
# HIGH_PRO                                                            1
# VEGAN                                                               1
# LOW_FAT                                                           NaN
# LOW_CAR                                                           NaN
# LOW_ENG                                                           NaN
# Name: 493, dtype: object

# %%
# 특정 행(index)을 출력 (예시에서는 2번째 행)
specific_row = dataset.iloc[5]  # 0부터 시작하는 인덱스

# 결과 출력
print(specific_row)
# Out:
# Unnamed: 0                                                          5
# ATT_FILE_NO_MAIN    http://www.foodsafetykorea.go.kr/uploadimg/coo...
# ATT_FILE_NO_MK      http://www.foodsafetykorea.go.kr/uploadimg/coo...
# HASH_TAG                                                         저염된장
# INFO_CAR                                                         12.0
# INFO_ENG                                                        100.0
# INFO_FAT                                                          0.0
# INFO_NA                                                         361.0
# INFO_PRO                                                         13.0
# INFO_WGT                                                          NaN
# MANUAL_IMG01                                                      NaN
# MANUAL_IMG02                                                      NaN
# MANUAL_IMG03        http://www.foodsafetykorea.go.kr/uploadimg/coo...
# MANUAL_IMG04        http://www.foodsafetykorea.go.kr/uploadimg/coo...
# MANUAL_IMG05        http://www.foodsafetykorea.go.kr/uploadimg/coo...
# MANUAL_IMG06                                                      NaN
# MANUAL01                                                          NaN
# MANUAL02                                                          NaN
# MANUAL03            3. 황태는 손질하여 물에 헹궈 건져 놓고 콩나물은 다듬어 씻고 청양고추는 어슷썰기...
# MANUAL04            4. 냄비에 물을 붓고 황태와 무를 넣고 끓인 후 육수에서 물을 건져내고 저염 된장...
# MANUAL05                 5. 콩나물, 다진 마늘, 청양고추를 넣고 뚜껑을 덮어 김이 나게 끓\n여준다.
# MANUAL06                                                          NaN
# RCP_NA_TIP          황태해장국을 조리할 때 소금 대신 저염된장을 사용하면 덜 짜고 감칠맛 나는 황태해장...
# RCP_NM                                             저염 된장으로 맛을 낸 황태해장국
# RCP_PARTS_DTLS      황태해장국\n황태(채) 15g(10개), 콩나물 30g(1/6봉지), 무 30g(5...
# RCP_PAT2                                                         국&찌개
# RCP_SEQ                                                          36.0
# RCP_WAY2                                                          끓이기
# LOW_NA                                                            0.0
# HIGH_PRO                                                            1
# VEGAN                                                               1
# LOW_FAT                                                           NaN
# LOW_CAR                                                           NaN
# LOW_ENG                                                           NaN
# Name: 5, dtype: object

# %%
dataset[['INFO_CAR','INFO_ENG','INFO_FAT']].describe()
# Out:
#           INFO_CAR     INFO_ENG     INFO_FAT
# count  1267.000000  1267.000000  1267.000000
# mean     29.341949   253.147837     9.738011
# std      61.790127   183.341981    18.350055
# min       0.000000     1.000000     0.000000
# 25%       8.570000   119.250000     2.225000
# 50%      18.600000   215.000000     6.000000
# 75%      38.550000   342.000000    12.715000
# max    1838.000000  1555.900000   505.000000

# %%
pca_pre_data = dataset.iloc[:,[4, 5, 6]]

# %%
import seaborn as sns
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d import proj3d
sns.pairplot(dataset[['INFO_CAR','INFO_ENG','INFO_FAT']],hue="INFO_ENG")
plt.show()

# %%
import seaborn as sns
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d import proj3d
sns.pairplot(dataset[['INFO_CAR','INFO_ENG','INFO_FAT']],hue="INFO_CAR")
plt.show()

# %%
import seaborn as sns
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d import proj3d
sns.pairplot(dataset[['INFO_CAR','INFO_ENG','INFO_FAT']],hue="INFO_FAT")
plt.show()

# %%
info_nu=dataset[['Unnamed: 0','INFO_CAR','INFO_ENG','INFO_FAT','INFO_NA','INFO_PRO']]
nu_df=dataset[['INFO_CAR','INFO_ENG','INFO_FAT','INFO_NA','INFO_PRO']]

# %%
# StandardScaler객체 생성
scaler = StandardScaler()
# StandardScaler 로 데이터 셋 변환. fit( ) 과 transform( ) 호출.
scaler.fit(pca_pre_data)
nu_scaled = scaler.transform(pca_pre_data)
#표준화 완료

# %%
nu_df_scaled = pd.DataFrame(data=nu_scaled, columns=['INFO_CAR','INFO_ENG','INFO_FAT'])
print('feature 들의 평균 값')
print(nu_df_scaled.mean())
print('\nfeature 들의 분산 값')
print(nu_df_scaled.var())
# Out:
# feature 들의 평균 값
# INFO_CAR    1.121614e-17
# INFO_ENG    1.962825e-17
# INFO_FAT   -5.047265e-17
# dtype: float64
#
# feature 들의 분산 값
# INFO_CAR    1.00079
# INFO_ENG    1.00079
# INFO_FAT    1.00079
# dtype: float64

# %%
record_df=nu_df_scaled.copy()
record_df['Unnamed: 0']=dataset['Unnamed: 0']

# %%
record_df.head()
# Out:
#    INFO_CAR  INFO_ENG  INFO_FAT  Unnamed: 0
# 0 -0.426482 -0.180869  0.395904           0
# 1 -0.151248 -0.208151 -0.040234           1
# 2 -0.329340 -1.135747 -0.476372           2
# 3 -0.313150 -0.972053 -0.421855           3
# 4 -0.442672 -1.026618 -0.476372           4

# %%
#신뢰구간 대략 95%구간 이외의 값을 outlier
# check Z score
df_Zscore = pd.DataFrame()
outlier_dict = {}
outlier_idx_list = []

for one_col in nu_df_scaled.columns:
    print("Check",one_col)
    df_Zscore[f'{one_col}_Zscore'] = sp.stats.zscore(nu_df_scaled[one_col])
    outlier_dict[one_col] = df_Zscore[f'{one_col}_Zscore'][(df_Zscore[f'{one_col}_Zscore']>2)|(df_Zscore[f'{one_col}_Zscore']<-2)]
    outlier_idx_list.append(list(outlier_dict[one_col].index))
    if len(outlier_dict[one_col]):
        print(one_col,'Has outliers\n', outlier_dict[one_col])
    else:
        print(one_col,"Has Not outlier")
    print()


print("Before", nu_df_scaled.shape)
all_outlier_idx = sum(outlier_idx_list,[])
nu_df_scaled = nu_df_scaled.drop(all_outlier_idx)
print("After (drop outlier)", nu_df_scaled.shape)
# Out:
# Check INFO_CAR
# INFO_CAR Has outliers
#  61      12.558063
# 868     29.282546
# 925      6.736065
# 1133     2.002049
# 1245     2.400814
# Name: INFO_CAR_Zscore, dtype: float64
#
# Check INFO_ENG
# INFO_ENG Has outliers
#  72      4.230664
# 100     2.350920
# 105     3.602628
# 135     2.022988
# 165     2.221056
# 185     3.141558
# 230     2.100469
# 234     2.611738
# 301     2.137573
# 302     2.015349
# 323     2.271256
# 327     2.664120
# 333     2.685945
# 355     2.362378
# 436     2.200322
# 467     2.201413
# 474     2.270164
# 616     3.687748
# 625     2.195411
# 791     5.772109
# 809     3.242502
# 827     2.020805
# 830     3.075535
# 917     2.629198
# 928     2.633018
# 992     2.229787
# 993     2.172494
# 1012    2.324183
# 1019    2.400028
# 1105    3.121369
# 1113    2.209052
# 1133    3.098452
# 1145    3.318347
# 1162    2.723049
# 1179    4.289048
# 1184    2.969135
# 1192    4.215386
# 1196    2.147395
# 1197    2.328003
# 1199    3.676290
# 1204    7.108391
# 1218    2.223348
# 1220    2.097632
# 1223    2.499772
# 1224    2.120603
# 1226    3.256580
# 1240    3.916428
# 1241    3.791475
# 1245    2.442806
# 1247    2.349283
# 1258    5.315623
# 1265    3.007057
# 1266    2.107126
# Name: INFO_ENG_Zscore, dtype: float64
#
# Check INFO_FAT
# INFO_FAT Has outliers
#  135      2.036874
# 185      2.162263
# 187      8.949663
# 230      2.151360
# 454     27.000330
# 467      2.249491
# 1012     2.064132
# 1105     2.238587
# 1145     2.903698
# 1179     4.675509
# 1192     4.811802
# 1199     3.089057
# 1204     7.145141
# 1226     2.048322
# 1240     2.081033
# 1241     2.181889
# 1247     2.107201
# 1258     3.049259
# 1265     2.630021
# Name: INFO_FAT_Zscore, dtype: float64
#
# Before (1267, 3)
# After (drop outlier) (1209, 3)

# %%
print(record_df.iloc[1189:1200])
# Out:
#       INFO_CAR  INFO_ENG  INFO_FAT  Unnamed: 0
# 1242  0.453780  0.552749 -0.136185      214201
# 1243  1.057998  1.605788 -0.075671      214202
# 1244  0.150214  0.464410  0.271604      214203
# 1246 -0.131496  0.105376  0.240530      214205
# 1248  0.287345  0.583906  0.215997      215579
# 1249 -0.129715  0.354735  0.241620      215580
# 1250  0.415733  1.945015  1.596374      215581
# 1251 -0.023831  1.769700  0.941622      215582
# 1252 -0.283198 -0.501435 -0.301372      215583
# 1253 -0.216657 -0.613674 -0.172711      215584
# 1254  0.293011  0.426214  0.094968      215585

# %%
#이상치 값 제거 -> 정규화, 반드시 이 순서
from sklearn.preprocessing import MinMaxScaler

# MinMaxScaler객체 생성
min_max_scaler = MinMaxScaler()

# transform()시 scale 변환된 데이터 셋이 numpy ndarry로 반환되어 이를 DataFrame으로 변환
#final_df_scaled = pd.DataFrame(min_max_scaler.fit_transform(nu_df_scaled),columns=['INFO_CAR','INFO_ENG','INFO_FAT'])
#print('feature들의 최소 값')
#print(final_df_scaled.min())
#print('\nfeature들의 최대 값')
#print(final_df_scaled.max())

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
pca_data = pca.fit_transform(nu_df_scaled)
print(pca_data.shape)
# Out:
# (1209, 2)

# %%
print(np.sum(pca.explained_variance_ratio_)) # 0.965...
# Out:
# 0.9727204320917866

# %%
pca.explained_variance_ratio_
# Out:
# array([0.81939465, 0.15332578])

# %%
data2 = pd.DataFrame(data =pca_data, columns=['pc1', 'pc2'])

# %%
data2.head()
# Out:
#         pc1       pc2
# 0  0.038109  0.606473
# 1 -0.074920  0.103316
# 2 -1.108964  0.001759
# 3 -0.939066  0.012652
# 4 -1.043144  0.062032

# %%
from sklearn.cluster import KMeans
WCSS=[]

# %%
plt.scatter(data2['pc1'], data2['pc2'])
plt.xlabel('pc1')
plt.ylabel('pc2')
plt.show()

# %% [markdown]
# 열량, 나트륨 수치가 range가 차이가 심해서 정규화 해야함.

# %%
for i in range (1,11):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=0)
    kmeans.fit(data2)
    interia=kmeans.inertia_
    #### inertia_ is the formula used to segregate the data points into clusters
    #### inertia = 관성
    #### Cluster 간의 거리의 합을 나타내는 inertia가 급격히 떨어지는 구간이 생기는데 => 이 부분이 팔꿈치와 유사해서
    #### 이 지점의 K 값을 군집(cluster)의 개수로 사용 inertia_속성으로 확인할 수 있다
    print('k:', i, 'inertia:', interia)
    WCSS.append(kmeans.inertia_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# k: 1 inertia: 1111.7875610949243
# k: 2 inertia: 463.51240797173995
# k: 3 inertia: 310.441217616118
# k: 4 inertia: 234.68402327269547
# k: 5 inertia: 185.118279179939
# k: 6 inertia: 143.29372134695032
# k: 7 inertia: 122.83821262124047
# k: 8 inertia: 107.77510264263425
# k: 9 inertia: 97.82191968885758
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# k: 10 inertia: 89.33291004575733

# %%
plt.plot(range(1,11), WCSS)

plt.title('The Elbow Method')
plt.xlabel('no of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
kmeansmodel = KMeans(n_clusters= 2, init='k-means++', max_iter=1000, random_state=0) #K-MEANS 알고리즘을 사용, K-Means 알고리즘이 수렴할 때까지 최대 300번 반복
y_kmeans= kmeansmodel.fit_predict(data2)
y_kmeans #각 데이터에 대해 클러스터 표현 0~1까지
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# array([0, 0, 0, ..., 1, 1, 0], dtype=int32)

# %%
data2['labels'] = y_kmeans

# %%
nu_df_scaled['labels']=y_kmeans

# %%
record_df['labels']=y_kmeans

# %%
data2.head(10)
# Out:
#         pc1       pc2  labels
# 0  0.038109  0.606473       0
# 1 -0.074920  0.103316       0
# 2 -1.108964  0.001759       0
# 3 -0.939066  0.012652       0
# 4 -1.043144  0.062032       0
# 5 -0.850352 -0.106750       0
# 6 -1.276735  0.040002       0
# 7 -1.117781  0.022723       0
# 8 -0.261876  0.329260       0
# 9 -0.209415 -0.152522       0

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1209 entries, 0 to 1208
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   pc1     1209 non-null   float64
#  1   pc2     1209 non-null   float64
#  2   labels  1209 non-null   int32
# dtypes: float64(2), int32(1)
# memory usage: 23.7 KB

# %%
sns.scatterplot(x=data2['pc1'], y=data2['pc2'], hue='labels', data=data2)
plt.scatter(kmeansmodel.cluster_centers_[:, 0], kmeansmodel.cluster_centers_[:, 1], s=300, c='yellow', label='Centroids')

# %%
selected_columns = data2.iloc[:, [0, 1]]

# %%
from sklearn.metrics import silhouette_score
k_range=range(2,10)
best_k=-1
best_sc=-1

for k in k_range:
  kmeans=KMeans(n_clusters=k,random_state=200)
  result=kmeans.fit_predict(selected_columns)
  score=silhouette_score(selected_columns,result)
  print('k: ',k,' score: ',score)
  if(score>best_sc):
    best_k=k
    best_sc=score
print('best_k: ',best_k)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# k:  2  score:  0.5153988371728352
# k:  3  score:  0.4545093644842157
# k:  4  score:  0.44624718933872537
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# k:  5  score:  0.41182253867290586
# k:  6  score:  0.4163665789786375
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# k:  7  score:  0.39557825638542254
# k:  8  score:  0.38586561632408795
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# k:  9  score:  0.3815466179819207
# best_k:  2

# %%
type(data2)
# Out:
# pandas.core.frame.DataFrame

# %%
cluster_size=data2['labels'].value_counts()
cluster_size.plot(kind='bar')
# Out:
# <Axes: >

# %%
temp=nu_df_scaled.groupby(['labels']).mean()
cluster_mean=temp.transpose()
sns.heatmap(
    cluster_mean,
    annot=True,
    fmt='.2f',
    cmap='RdYlBu_r'
)
plt.show() #라벨을 기준으로 각 칼럼들의 평균 계산, 각 칼럼마다 작은 평균값이 작은 0번 그룹을 선택한다

# %%
fig, axes = plt.subplots(nrows=3, ncols=1, figsize=(10, 15))
# INFO_FAT에 대한 boxplot
sns.boxplot(data=nu_df_scaled, y='labels', x='INFO_FAT', orient='h', ax=axes[0])
axes[0].set_xlabel('INFO_FAT')

# INFO_CAR에 대한 boxplot
sns.boxplot(data=nu_df_scaled, y='labels', x='INFO_CAR', orient='h', ax=axes[1])
axes[1].set_xlabel('INFO_CAR')

# INFO_ENG에 대한 boxplot
sns.boxplot(data=nu_df_scaled, y='labels', x='INFO_ENG', orient='h', ax=axes[2])
axes[2].set_xlabel('INFO_ENG')

plt.tight_layout()
plt.show()

# %%
result=data2.copy()

# %%
from yellowbrick.cluster import SilhouetteVisualizer
visualizer_3 = SilhouetteVisualizer(kmeansmodel, colors='yellowbrick')
result=result.drop(['labels'],axis='columns')

# %%
result.head(5)
# Out:
#         pc1       pc2
# 0  0.038109  0.606473
# 1 -0.074920  0.103316
# 2 -1.108964  0.001759
# 3 -0.939066  0.012652
# 4 -1.043144  0.062032

# %%
visualizer_3.fit(result)
visualizer_3.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but KMeans was fitted with feature names
#   warnings.warn(
# <Axes: title={'center': 'Silhouette Plot of KMeans Clustering for 1209 Samples in 2 Centers'}, xlabel='silhouette coefficient values', ylabel='cluster label'>

# %%
result.loc[:,'clusterID'] = visualizer_3.predict(result)
#실루엣 계수 컬럼 생성
result.loc[:,'silhouette coefficient'] = visualizer_3.silhouette_samples_

result.shape
result.head(5)
# Out:
#         pc1       pc2  clusterID  silhouette coefficient
# 0  0.038109  0.606473          0                0.244057
# 1 -0.074920  0.103316          0                0.459123
# 2 -1.108964  0.001759          0                0.718914
# 3 -0.939066  0.012652          0                0.746780
# 4 -1.043144  0.062032          0                0.729871

# %%
print('전체 데이터의 실루엣 계수 평균')
result['silhouette coefficient'].mean()
# Out:
# 전체 데이터의 실루엣 계수 평균
# 0.5153988371728352

# %%
print('\n군집별 실루엣 계수 평균')
result.groupby('clusterID')['silhouette coefficient'].mean().reset_index()
# Out:
# 군집별 실루엣 계수 평균
#    clusterID  silhouette coefficient
# 0          0                0.619897
# 1          1                0.347028

# %%
nu_df_scaled.head()
# Out:
#    INFO_CAR  INFO_ENG  INFO_FAT  labels
# 0 -0.426482 -0.180869  0.395904       0
# 1 -0.151248 -0.208151 -0.040234       0
# 2 -0.329340 -1.135747 -0.476372       0
# 3 -0.313150 -0.972053 -0.421855       0
# 4 -0.442672 -1.026618 -0.476372       0

# %%
record_df.head()
# Out:
#    INFO_CAR  INFO_ENG  INFO_FAT  Unnamed: 0  labels
# 0 -0.426482 -0.180869  0.395904           0       0
# 1 -0.151248 -0.208151 -0.040234           1       0
# 2 -0.329340 -1.135747 -0.476372           2       0
# 3 -0.313150 -0.972053 -0.421855           3       0
# 4 -0.442672 -1.026618 -0.476372           4       0

# %%
merged_df = pd.merge(dataset, record_df, on=['Unnamed: 0'], how='outer')

# %%
merged_df.head()
# Out:
#    Unnamed: 0                                   ATT_FILE_NO_MAIN  \
# 0           0  http://www.foodsafetykorea.go.kr/uploadimg/coo...
# 1           1  http://www.foodsafetykorea.go.kr/uploadimg/coo...
# 2           2  http://www.foodsafetykorea.go.kr/uploadimg/coo...
# 3           3  http://www.foodsafetykorea.go.kr/uploadimg/coo...
# 4           4  http://www.foodsafetykorea.go.kr/uploadimg/coo...
#
#                                       ATT_FILE_NO_MK HASH_TAG  INFO_CAR_x  \
# 0  http://www.foodsafetykorea.go.kr/uploadimg/coo...      연두부         3.0
# 1  http://www.foodsafetykorea.go.kr/uploadimg/coo...     날콩가루        20.0
# 2  http://www.foodsafetykorea.go.kr/uploadimg/coo...    방울토마토         9.0
# 3  http://www.foodsafetykorea.go.kr/uploadimg/coo...      순두부        10.0
# 4  http://www.foodsafetykorea.go.kr/uploadimg/coo...      NaN         2.0
#
#    INFO_ENG_x  INFO_FAT_x  INFO_NA  INFO_PRO  INFO_WGT  ... LOW_NA HIGH_PRO  \
# 0       220.0        17.0     99.0      14.0       NaN  ...    0.0        1
# 1       215.0         9.0    240.0      14.0       NaN  ...    0.0        1
# 2        45.0         1.0    277.0       2.0       NaN  ...    0.0        0
# 3        75.0         2.0     22.0       4.0       NaN  ...    0.0        0
# 4        65.0         1.0     78.0      12.0       NaN  ...    0.0        1
#
#   VEGAN LOW_FAT LOW_CAR LOW_ENG INFO_CAR_y INFO_ENG_y INFO_FAT_y labels
# 0     1     NaN     NaN     NaN  -0.426482  -0.180869   0.395904    0.0
# 1     1     NaN     NaN     NaN  -0.151248  -0.208151  -0.040234    0.0
# 2     1     NaN     NaN     NaN  -0.329340  -1.135747  -0.476372    0.0
# 3     1     NaN     NaN     NaN  -0.313150  -0.972053  -0.421855    0.0
# 4     1     NaN     NaN     NaN  -0.442672  -1.026618  -0.476372    0.0
#
# [5 rows x 38 columns]

# %%
print(merged_df.iloc[1189:1200])
# Out:
#       Unnamed: 0 ATT_FILE_NO_MAIN ATT_FILE_NO_MK HASH_TAG  INFO_CAR_x  \
# 1189      207822              NaN            NaN      NaN       120.7
# 1190      207821              NaN            NaN      NaN        32.8
# 1191      207820              NaN            NaN      NaN        13.7
# 1192      207819              NaN            NaN      NaN        36.9
# 1193      207818              NaN            NaN      NaN        62.4
# 1194      207817              NaN            NaN      NaN        15.2
# 1195      207826              NaN            NaN      NaN        48.4
# 1196      207946              NaN            NaN      NaN       102.6
# 1197      207948              NaN            NaN      NaN       106.0
# 1198      207947              NaN            NaN      NaN        46.2
# 1199      207955              NaN            NaN      NaN        42.9
#
#       INFO_ENG_x  INFO_FAT_x  INFO_NA  INFO_PRO  INFO_WGT  ... LOW_NA  \
# 1189       584.3         5.1    988.0      11.8       NaN  ...    NaN
# 1190       512.4        37.6    597.7      12.0       NaN  ...    NaN
# 1191       270.5        16.0    688.2      19.4       NaN  ...    NaN
# 1192      1025.7        98.0    503.6       4.8       NaN  ...    NaN
# 1193       238.1         0.6    987.3       8.9       NaN  ...    NaN
# 1194       183.9         9.7    174.9      11.7       NaN  ...    NaN
# 1195       232.1         3.6     68.3       6.5       NaN  ...    NaN
# 1196       646.7        16.1    808.0      25.9       NaN  ...    NaN
# 1197       679.8        15.3    664.5      27.7       NaN  ...    NaN
# 1198       248.0         1.1    898.3      15.0       NaN  ...    NaN
# 1199       926.9        66.4   1479.7      38.8       NaN  ...    NaN
#
#      HIGH_PRO VEGAN LOW_FAT LOW_CAR LOW_ENG INFO_CAR_y INFO_ENG_y INFO_FAT_y  \
# 1189        0     1     NaN     NaN     NaN   1.479106   1.806913  -0.252852
# 1190        0     0     NaN     NaN     NaN   0.055987   1.414594   1.518959
# 1191        1     0     NaN     NaN     NaN  -0.253246   0.094681   0.341387
# 1192        0     1     NaN     NaN     NaN        NaN        NaN        NaN
# 1193        0     1     NaN     NaN     NaN   0.535217  -0.082108  -0.498179
# 1194        1     0     NaN     NaN     NaN  -0.228961  -0.377847  -0.002072
# 1195        0     1     NaN     NaN     NaN   0.308554  -0.114846  -0.334628
# 1196        0     1     NaN     NaN     NaN        NaN        NaN        NaN
# 1197        0     1     NaN     NaN     NaN        NaN        NaN        NaN
# 1198        1     1     NaN     NaN     NaN   0.272935  -0.028089  -0.470921
# 1199        0     0     NaN     NaN     NaN        NaN        NaN        NaN
#
#      labels
# 1189    1.0
# 1190    1.0
# 1191    1.0
# 1192    NaN
# 1193    0.0
# 1194    0.0
# 1195    0.0
# 1196    NaN
# 1197    NaN
# 1198    0.0
# 1199    NaN
#
# [11 rows x 38 columns]

# %%
merged_df['LOW_NA'] = merged_df['RCP_NA_TIP'].notnull().astype(int)

# %%
print(merged_df.iloc[1189:1200])
# Out:
#       Unnamed: 0 ATT_FILE_NO_MAIN ATT_FILE_NO_MK HASH_TAG  INFO_CAR_x  \
# 1189      207822              NaN            NaN      NaN       120.7
# 1190      207821              NaN            NaN      NaN        32.8
# 1191      207820              NaN            NaN      NaN        13.7
# 1192      207819              NaN            NaN      NaN        36.9
# 1193      207818              NaN            NaN      NaN        62.4
# 1194      207817              NaN            NaN      NaN        15.2
# 1195      207826              NaN            NaN      NaN        48.4
# 1196      207946              NaN            NaN      NaN       102.6
# 1197      207948              NaN            NaN      NaN       106.0
# 1198      207947              NaN            NaN      NaN        46.2
# 1199      207955              NaN            NaN      NaN        42.9
#
#       INFO_ENG_x  INFO_FAT_x  INFO_NA  INFO_PRO  INFO_WGT  ... LOW_NA  \
# 1189       584.3         5.1    988.0      11.8       NaN  ...      0
# 1190       512.4        37.6    597.7      12.0       NaN  ...      0
# 1191       270.5        16.0    688.2      19.4       NaN  ...      0
# 1192      1025.7        98.0    503.6       4.8       NaN  ...      0
# 1193       238.1         0.6    987.3       8.9       NaN  ...      0
# 1194       183.9         9.7    174.9      11.7       NaN  ...      0
# 1195       232.1         3.6     68.3       6.5       NaN  ...      0
# 1196       646.7        16.1    808.0      25.9       NaN  ...      0
# 1197       679.8        15.3    664.5      27.7       NaN  ...      0
# 1198       248.0         1.1    898.3      15.0       NaN  ...      0
# 1199       926.9        66.4   1479.7      38.8       NaN  ...      0
#
#      HIGH_PRO VEGAN LOW_FAT LOW_CAR LOW_ENG INFO_CAR_y INFO_ENG_y INFO_FAT_y  \
# 1189        0     1     NaN     NaN     NaN   1.479106   1.806913  -0.252852
# 1190        0     0     NaN     NaN     NaN   0.055987   1.414594   1.518959
# 1191        1     0     NaN     NaN     NaN  -0.253246   0.094681   0.341387
# 1192        0     1     NaN     NaN     NaN        NaN        NaN        NaN
# 1193        0     1     NaN     NaN     NaN   0.535217  -0.082108  -0.498179
# 1194        1     0     NaN     NaN     NaN  -0.228961  -0.377847  -0.002072
# 1195        0     1     NaN     NaN     NaN   0.308554  -0.114846  -0.334628
# 1196        0     1     NaN     NaN     NaN        NaN        NaN        NaN
# 1197        0     1     NaN     NaN     NaN        NaN        NaN        NaN
# 1198        1     1     NaN     NaN     NaN   0.272935  -0.028089  -0.470921
# 1199        0     0     NaN     NaN     NaN        NaN        NaN        NaN
#
#      labels
# 1189    1.0
# 1190    1.0
# 1191    1.0
# 1192    NaN
# 1193    0.0
# 1194    0.0
# 1195    0.0
# 1196    NaN
# 1197    NaN
# 1198    0.0
# 1199    NaN
#
# [11 rows x 38 columns]

# %%
merged_df.head()
# Out:
#    Unnamed: 0                                   ATT_FILE_NO_MAIN  \
# 0           0  http://www.foodsafetykorea.go.kr/uploadimg/coo...
# 1           1  http://www.foodsafetykorea.go.kr/uploadimg/coo...
# 2           2  http://www.foodsafetykorea.go.kr/uploadimg/coo...
# 3           3  http://www.foodsafetykorea.go.kr/uploadimg/coo...
# 4           4  http://www.foodsafetykorea.go.kr/uploadimg/coo...
#
#                                       ATT_FILE_NO_MK HASH_TAG  INFO_CAR_x  \
# 0  http://www.foodsafetykorea.go.kr/uploadimg/coo...      연두부         3.0
# 1  http://www.foodsafetykorea.go.kr/uploadimg/coo...     날콩가루        20.0
# 2  http://www.foodsafetykorea.go.kr/uploadimg/coo...    방울토마토         9.0
# 3  http://www.foodsafetykorea.go.kr/uploadimg/coo...      순두부        10.0
# 4  http://www.foodsafetykorea.go.kr/uploadimg/coo...      NaN         2.0
#
#    INFO_ENG_x  INFO_FAT_x  INFO_NA  INFO_PRO  INFO_WGT  ... LOW_NA HIGH_PRO  \
# 0       220.0        17.0     99.0      14.0       NaN  ...      1        1
# 1       215.0         9.0    240.0      14.0       NaN  ...      1        1
# 2        45.0         1.0    277.0       2.0       NaN  ...      1        0
# 3        75.0         2.0     22.0       4.0       NaN  ...      1        0
# 4        65.0         1.0     78.0      12.0       NaN  ...      1        1
#
#   VEGAN LOW_FAT LOW_CAR LOW_ENG INFO_CAR_y INFO_ENG_y INFO_FAT_y labels
# 0     1     NaN     NaN     NaN  -0.426482  -0.180869   0.395904    0.0
# 1     1     NaN     NaN     NaN  -0.151248  -0.208151  -0.040234    0.0
# 2     1     NaN     NaN     NaN  -0.329340  -1.135747  -0.476372    0.0
# 3     1     NaN     NaN     NaN  -0.313150  -0.972053  -0.421855    0.0
# 4     1     NaN     NaN     NaN  -0.442672  -1.026618  -0.476372    0.0
#
# [5 rows x 38 columns]

# %%
merged_df['labels'] = merged_df['labels'].apply(lambda x: 0 if x == 1 else (1 if x == 0 else x))

# %%
merged_df.head()
# Out:
#    Unnamed: 0                                   ATT_FILE_NO_MAIN  \
# 0           0  http://www.foodsafetykorea.go.kr/uploadimg/coo...
# 1           1  http://www.foodsafetykorea.go.kr/uploadimg/coo...
# 2           2  http://www.foodsafetykorea.go.kr/uploadimg/coo...
# 3           3  http://www.foodsafetykorea.go.kr/uploadimg/coo...
# 4           4  http://www.foodsafetykorea.go.kr/uploadimg/coo...
#
#                                       ATT_FILE_NO_MK HASH_TAG  INFO_CAR_x  \
# 0  http://www.foodsafetykorea.go.kr/uploadimg/coo...      연두부         3.0
# 1  http://www.foodsafetykorea.go.kr/uploadimg/coo...     날콩가루        20.0
# 2  http://www.foodsafetykorea.go.kr/uploadimg/coo...    방울토마토         9.0
# 3  http://www.foodsafetykorea.go.kr/uploadimg/coo...      순두부        10.0
# 4  http://www.foodsafetykorea.go.kr/uploadimg/coo...      NaN         2.0
#
#    INFO_ENG_x  INFO_FAT_x  INFO_NA  INFO_PRO  INFO_WGT  ... LOW_NA HIGH_PRO  \
# 0       220.0        17.0     99.0      14.0       NaN  ...      1        1
# 1       215.0         9.0    240.0      14.0       NaN  ...      1        1
# 2        45.0         1.0    277.0       2.0       NaN  ...      1        0
# 3        75.0         2.0     22.0       4.0       NaN  ...      1        0
# 4        65.0         1.0     78.0      12.0       NaN  ...      1        1
#
#   VEGAN LOW_FAT LOW_CAR LOW_ENG INFO_CAR_y INFO_ENG_y INFO_FAT_y labels
# 0     1     NaN     NaN     NaN  -0.426482  -0.180869   0.395904    1.0
# 1     1     NaN     NaN     NaN  -0.151248  -0.208151  -0.040234    1.0
# 2     1     NaN     NaN     NaN  -0.329340  -1.135747  -0.476372    1.0
# 3     1     NaN     NaN     NaN  -0.313150  -0.972053  -0.421855    1.0
# 4     1     NaN     NaN     NaN  -0.442672  -1.026618  -0.476372    1.0
#
# [5 rows x 38 columns]

# %%
print(merged_df.iloc[1189:1200])
# Out:
#       Unnamed: 0 ATT_FILE_NO_MAIN ATT_FILE_NO_MK HASH_TAG  INFO_CAR_x  \
# 1189      207822              NaN            NaN      NaN       120.7
# 1190      207821              NaN            NaN      NaN        32.8
# 1191      207820              NaN            NaN      NaN        13.7
# 1192      207819              NaN            NaN      NaN        36.9
# 1193      207818              NaN            NaN      NaN        62.4
# 1194      207817              NaN            NaN      NaN        15.2
# 1195      207826              NaN            NaN      NaN        48.4
# 1196      207946              NaN            NaN      NaN       102.6
# 1197      207948              NaN            NaN      NaN       106.0
# 1198      207947              NaN            NaN      NaN        46.2
# 1199      207955              NaN            NaN      NaN        42.9
#
#       INFO_ENG_x  INFO_FAT_x  INFO_NA  INFO_PRO  INFO_WGT  ... LOW_NA  \
# 1189       584.3         5.1    988.0      11.8       NaN  ...      0
# 1190       512.4        37.6    597.7      12.0       NaN  ...      0
# 1191       270.5        16.0    688.2      19.4       NaN  ...      0
# 1192      1025.7        98.0    503.6       4.8       NaN  ...      0
# 1193       238.1         0.6    987.3       8.9       NaN  ...      0
# 1194       183.9         9.7    174.9      11.7       NaN  ...      0
# 1195       232.1         3.6     68.3       6.5       NaN  ...      0
# 1196       646.7        16.1    808.0      25.9       NaN  ...      0
# 1197       679.8        15.3    664.5      27.7       NaN  ...      0
# 1198       248.0         1.1    898.3      15.0       NaN  ...      0
# 1199       926.9        66.4   1479.7      38.8       NaN  ...      0
#
#      HIGH_PRO VEGAN LOW_FAT LOW_CAR LOW_ENG INFO_CAR_y INFO_ENG_y INFO_FAT_y  \
# 1189        0     1     NaN     NaN     NaN   1.479106   1.806913  -0.252852
# 1190        0     0     NaN     NaN     NaN   0.055987   1.414594   1.518959
# 1191        1     0     NaN     NaN     NaN  -0.253246   0.094681   0.341387
# 1192        0     1     NaN     NaN     NaN        NaN        NaN        NaN
# 1193        0     1     NaN     NaN     NaN   0.535217  -0.082108  -0.498179
# 1194        1     0     NaN     NaN     NaN  -0.228961  -0.377847  -0.002072
# 1195        0     1     NaN     NaN     NaN   0.308554  -0.114846  -0.334628
# 1196        0     1     NaN     NaN     NaN        NaN        NaN        NaN
# 1197        0     1     NaN     NaN     NaN        NaN        NaN        NaN
# 1198        1     1     NaN     NaN     NaN   0.272935  -0.028089  -0.470921
# 1199        0     0     NaN     NaN     NaN        NaN        NaN        NaN
#
#      labels
# 1189    0.0
# 1190    0.0
# 1191    0.0
# 1192    NaN
# 1193    1.0
# 1194    1.0
# 1195    1.0
# 1196    NaN
# 1197    NaN
# 1198    1.0
# 1199    NaN
#
# [11 rows x 38 columns]

# %%
merged_df.to_csv('final_nutrient.csv', index = None, encoding='utf-8')
